# %%
print("hola mundo")
# Out:
# hola mundo

# %%
#orden de ejecucion:

fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana"
print(fruta)
# Out:
# naranja
# 4
# banana

# %% [markdown]
# # TIPOS DE DATOS

# %%
edad = 28 #--> Integer
altura = 1.80 #--> float
nombre = "Manfred"# --->
print(edad,altura,nombre)
# Out:
# 28 1.8 Manfred

# %%
nombre = "Manfred"
edad =  26
Ciudad = "Asuncion"

print(nombre,edad,Ciudad)
# Out:
# Manfred 26 Asuncion

# %%
cantidad_de_frutasantidad_de_manzanas = 10
cantidad_de_naranjas = 8
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print('Total de frutas:', cantidad_de_frutas)

-frutas_vendidas = 16
cantidad_de_frutas = cantidad_de_frutas - frutas_vendidas
print('Frutas restantes:', cantidad_de_frutas)
# Out:
# Total de frutas: 18
# Frutas restantes: 2

# %%
nombre = "lucas"    
apellido = "fleitas" 
print(f"Hola me llamo {nombre} {apellido} mucho gusto!")
# Out:
# Hola me llamo lucas fleitas mucho gusto!

# %%
nombre = input("Escribe tu nombre")
print(nombre)

# %%
 #Solicita el usuario un producto 
producto = input("Que producto quiere")
print(producto)

#solicitar al cliente que cantidad

cantidad_de_producto = input("que cantidad desea")
print(cantidad_de_producto)
# Out:
# 168

# %%
numero_uno = int(input("ingrese su primer numero"))
numero_dos = int(input("ingrese su segundo numero"))

suma_de_numero = numero_uno + numero_dos
print(f"la suma es igual a {suma_de_numero}")
# Out:
# la suma es igual a 336

# %%
def abrir_puerta():
    print("levantar y avanzar al frente \n")
abrir_puerta()
abrir_puerta()
abrir_puerta()
print("\n")
def cerrar_puerta():
    print("retrocerder, golepar y cerrar\n")
cerrar_puerta()
cerrar_puerta()
cerrar_puerta()
cerrar_puerta()
# Out:
# levantar y avanzar al frente
#
# levantar y avanzar al frente
#
# levantar y avanzar al frente
#
#
#
# retrocerder, golepar y cerrar
#
# retrocerder, golepar y cerrar
#
# retrocerder, golepar y cerrar
#
# retrocerder, golepar y cerrar

# %%
def preparar_helado(caracteristca1,caracteristica2):
    print(f"el healdo contiene dos sabores disponibles {caracteristca1,caracteristica2}")

sabor_de_helado1=input("ingrese un sabor del helado")
sabor_de_helado2 =input("ingrese el segundo sabor") 
preparar_helado(sabor_de_helado1,sabor_de_helado2)
# Out:
# el healdo contiene dos sabores disponibles ('Frutilla', 'chocolate')
